# %% [markdown]
# # Data Wrangling with DataFrames Coding Quiz
#
# Use this Jupyter notebook to find the answers to the quiz in the previous section. There is an answer key in the next part of the lesson.

# %%
from pyspark.sql import SparkSession

# TODOS: 
# 1) import any other libraries you might need
# 2) instantiate a Spark session 
# 3) read in the data set located at the path "data/sparkify_log_small.json"
# 4) write code to answer the quiz questions 

from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import desc
from pyspark.sql.functions import asc
from pyspark.sql.functions import sum as Fsum

import datetime

import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
spark = SparkSession \
    .builder \
    .appName("Wrangling Data") \
    .getOrCreate()

# %%
path = "data/sparkify_log_small.json"
user_log = spark.read.json(path)

# %% [markdown]
# # Question 1
#
# Which page did user id "" (empty string) NOT visit?

# %%
user_log.groupBy("page").count().show()
# Out:
# +----------------+-----+
# |            page|count|
# +----------------+-----+
# |Submit Downgrade|    1|
# |            Home| 1126|
# |       Downgrade|   75|
# |          Logout|  100|
# |   Save Settings|   11|
# |           About|   43|
# |        Settings|   59|
# |           Login|  126|
# |        NextSong| 8347|
# |            Help|   58|
# |         Upgrade|   32|
# |           Error|   12|
# |  Submit Upgrade|   10|
# +----------------+-----+

# %%
user_log.where(user_log.userId == "").groupBy("page").count().show()
# Out:
# +-----+-----+
# | page|count|
# +-----+-----+
# | Home|  187|
# |About|   15|
# |Login|  126|
# | Help|    8|
# +-----+-----+

# %% [markdown]
# TODO: write your code to answer question 1.
#
# Pages not visited by _uderId_ == __""__:
# - Submit Downgrade
# - Downgrade, Logout
# - Save Settings
# - Settings
# - NextSong
# - Upgrade
# - Error
# - Submit Upgrade

# %% [markdown]
# # Question 2 - Reflect
#
# What type of user does the empty string user id most likely refer to?

# %%
# TODO: use this space to explore the behavior of the user with an empty string
user_log.where(user_log.userId == "").groupBy("page").count().show()
# Out:
# +-----+-----+
# | page|count|
# +-----+-----+
# | Home|  187|
# |About|   15|
# |Login|  126|
# | Help|    8|
# +-----+-----+

# %% [markdown]
# A _test user_, employed just to check the behaviour of some basic features on the web page.

# %% [markdown]
# # Question 3
#
# How many female users do we have in the data set?

# %%
# TODO: write your code to answer question 3
user_log.dropDuplicates(['userId']).groupBy("gender").count().show()
# Out:
# +------+-----+
# |gender|count|
# +------+-----+
# |     F|  462|
# |  null|    1|
# |     M|  501|
# +------+-----+

# %% [markdown]
# There are 462 female users.

# %% [markdown]
# # Question 4
#
# How many songs were played from the most played artist?

# %%
# TODO: write your code to answer question 4
user_log.groupBy('artist').count().sort('count', ascending=False).show()
# Out:
# +--------------------+-----+
# |              artist|count|
# +--------------------+-----+
# |                null| 1653|
# |            Coldplay|   83|
# |       Kings Of Leon|   69|
# |Florence + The Ma...|   52|
# |            BjÃÂ¶rk|   46|
# |       Dwight Yoakam|   45|
# |       Justin Bieber|   43|
# |      The Black Keys|   40|
# |         OneRepublic|   37|
# |                Muse|   36|
# |        Jack Johnson|   36|
# |           Radiohead|   31|
# |        Taylor Swift|   29|
# |Barry Tuckwell/Ac...|   28|
# |          Lily Allen|   28|
# |               Train|   28|
# |           Daft Punk|   27|
# |           Metallica|   27|
# |          Nickelback|   27|
# |          Kanye West|   26|
# +--------------------+-----+
# only showing top 20 rows

# %%
user_log.select('artist', 'song').where(user_log.artist == 'Coldplay').groupBy('artist').count().show()
# Out:
# +--------+-----+
# |  artist|count|
# +--------+-----+
# |Coldplay|   83|
# +--------+-----+

# %% [markdown]
# # Question 5 (challenge)
#
# How many songs do users listen to on average between visiting our home page? Please round your answer to the closest integer.

# %%
# TODO: write your code to answer question 5
